# %% [markdown]
# ****| RETO 3: MERCADOTECNIA TELEFÓNICA CON APRENDIZAJE SUPERVISADO |****
#
# ====================================================================

# %%
# Manipulación y análisis de datos
import pandas as pd
import numpy as np

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report

# %% [markdown]
# **1. Preparación del entorno y carga de los datos**

# %%
# Carga de los datos
data = pd.read_csv("../data/bank_marketing.csv")

# %%
data.head(8)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   31  self-employed  married   tertiary      no     2666      no   no
# 1   29     unemployed   single    unknown      no     1584      no   no
# 2   41    blue-collar  married  secondary      no     2152     yes   no
# 3   50    blue-collar  married  secondary      no       84     yes   no
# 4   40         admin.  married  secondary      no        0      no   no
# 5   58        retired  married  secondary      no     8332      no   no
# 6   36       services   single  secondary      no      198     yes   no
# 7   26     technician   single  secondary      no     1231     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome    y
# 0  cellular   10   nov       318         2     97         6  success  yes
# 1  cellular    6   sep       245         1     -1         0  unknown  yes
# 2  cellular   17   nov       369         1     -1         0  unknown   no
# 3  cellular   17   jul        18         8     -1         0  unknown   no
# 4  cellular   28   jul       496         2    182        11  success  yes
# 5  cellular   13   aug       740         4     -1         0  unknown   no
# 6  cellular   11   may       496         1     -1         0  unknown   no
# 7  cellular    3   jun       385         2     96         5  success  yes

# %%
# Dimensiones del dataframe
print("Número de registros:", data.shape[0])
print("Número de variables:", data.shape[1])
# Out:
# Número de registros: 9000
# Número de variables: 17

# %%
# Tipos de variables
print("\nTipos de variables:")
print(data.dtypes)
# Out:
# Tipos de variables:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
# Datos faltantes
print("\nValores nulos por variable:")
print(data.isnull().sum())
# Out:
# Valores nulos por variable:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# Descripción general de los datos
data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  9000.000000   9000.000000  9000.000000  9000.000000  9000.000000
# mean     41.090556   1482.262778    15.619556   353.832778     2.520111
# std      11.664253   3031.013197     8.345305   336.945158     2.737758
# min      18.000000  -3058.000000     1.000000     3.000000     1.000000
# 25%      32.000000    109.000000     8.000000   131.000000     1.000000
# 50%      39.000000    519.000000    15.000000   240.500000     2.000000
# 75%      49.000000   1646.500000    21.000000   462.000000     3.000000
# max      95.000000  81204.000000    31.000000  3253.000000    58.000000
#
#              pdays     previous
# count  9000.000000  9000.000000
# mean     50.511333     0.788889
# std     107.691963     2.210273
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     850.000000    58.000000

# %% [markdown]
# Identificamos las siguientes variables
#
# ***Numéricas:*** age, balance, day, duration, campaing, pdays, previous
#
# ***Categóricas:*** job, marital, education, default, housing, loan, contact, month, poutcome, y
#
# ___

# %% [markdown]
# **2. Procesamiento de variables**

# %% [markdown]
# Optamos por emplear **LabelEncoder** para:
#
# *Variables con orden* **->** Existe una jerarquía lógica
#
# Y **OneHotEncoder** para:
#
# *Variables sin orden* **->** Para evitar introducir un orden 'ficticio' y sesgo en el modelo

# %%
# == Variable de salida == #
# Revisamos valores únicos de 'y'
print("Valores únicos en 'y':", data['y'].unique())
print("Distribución de 'y':")
print(data['y'].value_counts())
# Out:
# Valores únicos en 'y': ['yes' 'no']
# Distribución de 'y':
# y
# no     5213
# yes    3787
# Name: count, dtype: int64

# %%
print("\nClientes suscritos:", data['y'].value_counts())
# Out:
# Clientes suscritos: y
# 0    5213
# 1    3787
# Name: count, dtype: int64

# %%
# == Variables binarias simples == #
print("\nDefault:", data['default'].unique())
print("\nHousing:", data['housing'].unique())
print("\nLoan:",data['loan'].unique())
# Out:
# Default: ['no' 'yes']
#
# Housing: ['no' 'yes']
#
# Loan: ['no' 'yes']

# %%
# == Aplicamos OneHotEncoder a variables nominales == #
# Lista de columnas nominales
onehot_cols = ['job', 'marital', 'contact', 'month', 'poutcome']

# %%
data_encoded.head()
# Out:
#    age  education  default  balance  housing  loan  day  duration  campaign  \
# 0   31   tertiary        0     2666        0     0   10       318         2
# 1   29    unknown        0     1584        0     0    6       245         1
# 2   41  secondary        0     2152        1     0   17       369         1
# 3   50  secondary        0       84        1     0   17        18         8
# 4   40  secondary        0        0        0     0   28       496         2
#
#    pdays  ...  month_jul  month_jun  month_mar  month_may  month_nov  \
# 0     97  ...      False      False      False      False       True
# 1     -1  ...      False      False      False      False      False
# 2     -1  ...      False      False      False      False       True
# 3     -1  ...       True      False      False      False      False
# 4    182  ...       True      False      False      False      False
#
#    month_oct  month_sep  poutcome_other  poutcome_success  poutcome_unknown
# 0      False      False           False              True             False
# 1      False       True           False             False              True
# 2      False      False           False             False              True
# 3      False      False           False             False              True
# 4      False      False           False              True             False
#
# [5 rows x 41 columns]

# %% [markdown]
# En el caso de 'education', se identifica un orden implícito:
# 'primary' < 'secondary' < 'tertiary', con 'unknown' como caso especial.

# %%
print("\neducation:", data_encoded['education'].unique())
# Out:
# education: [3 0 2 1]

# %%
print("Shape final del dataset:", data_encoded.shape)
data_encoded.head()
# Out:
# Shape final del dataset: (9000, 41)
#    age  education  default  balance  housing  loan  day  duration  campaign  \
# 0   31          3        0     2666        0     0   10       318         2
# 1   29          0        0     1584        0     0    6       245         1
# 2   41          2        0     2152        1     0   17       369         1
# 3   50          2        0       84        1     0   17        18         8
# 4   40          2        0        0        0     0   28       496         2
#
#    pdays  ...  month_jul  month_jun  month_mar  month_may  month_nov  \
# 0     97  ...      False      False      False      False       True
# 1     -1  ...      False      False      False      False      False
# 2     -1  ...      False      False      False      False       True
# 3     -1  ...       True      False      False      False      False
# 4    182  ...       True      False      False      False      False
#
#    month_oct  month_sep  poutcome_other  poutcome_success  poutcome_unknown
# 0      False      False           False              True             False
# 1      False       True           False             False              True
# 2      False      False           False             False              True
# 3      False      False           False             False              True
# 4      False      False           False              True             False
#
# [5 rows x 41 columns]
